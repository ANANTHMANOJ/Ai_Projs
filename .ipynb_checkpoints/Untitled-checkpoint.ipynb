# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
m = [1,2,3,45]

# %%
type(m)
# Out:
# list

# %%
a=np.array(m)

# %%
a
# Out:
# array([ 1,  2,  3, 45])

# %%
type(a[1])
# Out:
# numpy.int64

# %%
np.arange(1,100,15)
# Out:
# array([ 1, 16, 31, 46, 61, 76, 91])

# %%
img=Image.open("/home/amnayak/Desktop/known/Ananth.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=413x531 at 0x7FF7B99E27F0>

# %%
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img_arr=np.asarray(img)

# %%
img_arr.shape
# Out:
# (531, 413, 4)

# %%
plt.imshow(img_arr)

# %%
plt.imshow(img_arr[:,:,1],cmap='gray')

# %%
img_arr[:,:,1]=0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-b939049d2b3e> in <module>
# ----> 1 img_arr[:,:,1]=0
#
# ValueError: assignment destination is read-only

# %%
arr=img_arr.copy()

# %%
arr.setflags(write=1)

# %%
arr[:,:,1]=0

# %%
plt.imshow(arr)

# %%
arr[:,:,2]=0

# %%
plt.imshow(arr)

# %%
ar=np.ones(25)*10

# %%
np.reshape(ar,(5,5))
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
np.random.seed(1)

# %%
ar=np.random.randint(0,100,(5,5))

# %%
ar
# Out:
# array([[37, 12, 72,  9, 75],
#        [ 5, 79, 64, 16,  1],
#        [76, 71,  6, 25, 50],
#        [20, 18, 84, 11, 28],
#        [29, 14, 50, 68, 87]])

# %%
ar.min()
# Out:
# 1

# %%
ar.max()
# Out:
# 87
